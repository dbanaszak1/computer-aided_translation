# %% [markdown]
# ![Logo 1](https://git.wmi.amu.edu.pl/AITech/Szablon/raw/branch/master/Logotyp_AITech1.jpg)
# <div class="alert alert-block alert-info">
# <h1> Komputerowe wspomaganie tłumaczenia </h1>
# <h2> 3. <i>Terminologia</i> [laboratoria]</h2>
# <h3>Rafał Jaworski (2021)</h3>
# </div>
#
# ![Logo 2](https://git.wmi.amu.edu.pl/AITech/Szablon/raw/branch/master/Logotyp_AITech2.jpg)

# %% [markdown]
# Na dzisiejszych zajęciach zajmiemy się bliżej słownikami używanymi do wspomagania tłumaczenia. Oczywiście na rynku dostępnych jest bardzo wiele słowników w formacie elektronicznym. Wiele z nich jest gotowych do użycia w SDL Trados, memoQ i innych narzędziach CAT. Zawierają one setki tysięcy lub miliony haseł i oferują natychmiastową pomoc tłumaczowi.

# %% [markdown]
# Problem jednak w tym, iż często nie zawierają odpowiedniej terminologii specjalistycznej - używanej przez klienta zamawiającego tłumaczenie. Terminy specjalistyczne są bardzo częste w tekstach tłumaczonych ze względu na następujące zjawiska:
# - Teksty o tematyce ogólnej są tłumaczone dość rzadko (nikt nie tłumaczy pocztówek z pozdrowieniami z wakacji...)
# - Te same słowa mogą mieć zarówno znaczenie ogólne, jak i bardzo specjalistyczne (np. "dziedziczenie" w kontekście prawnym lub informatycznym)
# - Klient używa nazw lub słów wymyślonych przez siebie, np. na potrzeby marketingowe.

# %% [markdown]
# Nietrywialnymi zadaniami stają się: odnalezienie terminu specjalistycznego w tekście źródłowym oraz podanie prawidłowego tłumaczenia tego terminu na język docelowy

# %% [markdown]
# Brzmi prosto? Spróbujmy wykonać ręcznie tę drugą operację.

# %% [markdown]
# ### Ćwiczenie 1: Podaj tłumaczenie terminu "prowadnice szaf metalowych" na język angielski. Opisz, z jakich narzędzi skorzystałaś/eś.

# %% [markdown]
# Odpowiedź:
#
# Metal locker slides. Na początku zorientowałem się jakie prowadnice montowane są w szafach metalowych. Wyszukałem w przeglądarce odpowiedź i okazało się, że najczęsciej występują prowadnice kulkowe. Sprawdziłem, więc w słowniku Diki, że takie prowadnice nazywają się: ball-bearing slide, a że w naszym haśle nie jest zdefiniowane jaka to prowadnica zostawiłem ogólną końcówkę slides. Następnie sprawdziłem, że metalowa szafka w słowniku Cambridge to locker.

# %% [markdown]
# W dalszych ćwiczeniach skupimy się jednak na odszukaniu terminu specjalistycznego w tekście. W tym celu będą potrzebne dwie operacje:
# 1. Przygotowanie słownika specjalistycznego.
# 2. Detekcja terminologii przy użyciu przygotowanego słownika specjalistycznego.

# %% [markdown]
# Zajmijmy się najpierw krokiem nr 2 (gdyż jest prostszy). Rozważmy następujący tekst:

# %%
text = " For all Java programmers:"
text += " This section explains how to compile and run a Swing application from the command line."
text += " For information on compiling and running a Swing application using NetBeans IDE,"
text += " see Running Tutorial Examples in NetBeans IDE. The compilation instructions work for all Swing programs"
text += " — applets, as well as applications. Here are the steps you need to follow:"
text += " Install the latest release of the Java SE platform, if you haven't already done so."
text += " Create a program that uses Swing components. Compile the program. Run the program."

# %% [markdown]
# Załóżmy, że posiadamy następujący słownik:

# %%
dictionary = ['program', 'application', 'applet', 'compile']

# %% [markdown]
# ### Ćwiczenie 2: Napisz program, który wypisze pozycje wszystkich wystąpień poszczególnych terminów specjalistycznych. Dla każdego terminu należy wypisać listę par (pozycja_startowa, pozycja końcowa).

# %%
def terminology_lookup(text, dictionary):
    results = {}
    
    for term in dictionary:
        occurrences = []
        start_search = 0
        while True:
            idx = text.find(term, start_search)
        
            if idx == -1:
                break
        
            occurrences.append((idx, idx + len(term)))
            start_search = idx + 1
            
        results[term] = occurrences
    
    return results

found_terms = terminology_lookup(text, dictionary)
for term, positions in found_terms.items():
    print(f"Termin: '{term}'")
    if positions:
        print(f"  Pozycje: {positions}")
    else:
        print("  Nie znaleziono.")
# Out:
# Termin: 'program'
#   Pozycje: [(14, 21), (291, 298), (468, 475), (516, 523), (533, 540)]
# Termin: 'application'
#   Pozycje: [(80, 91), (164, 175), (322, 333)]
# Termin: 'applet'
#   Pozycje: [(302, 308)]
# Termin: 'compile'
#   Pozycje: [(56, 63)]

# %% [markdown]
# Zwykłe wyszukiwanie w tekście ma pewne wady. Na przykład, gdy szukaliśmy słowa "program", złapaliśmy przypadkiem słowo "programmer". Złapaliśmy także słowo "programs", co jest poprawne, ale niepoprawnie podaliśmy jego pozycję w tekście.

# %% [markdown]
# Żeby poradzić sobie z tymi problemami, musimy wykorzystać techniki przetwarzania języka naturalnego. Wypróbujmy pakiet spaCy:
#
# `pip3 install spacy`
#
# oraz
#
# `python3 -m spacy download en_core_web_sm`

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting spacy
#   Downloading spacy-3.8.11-cp313-cp313-win_amd64.whl.metadata (28 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Downloading murmurhash-1.0.15-cp313-cp313-win_amd64.whl.metadata (2.3 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Downloading cymem-2.0.13-cp313-cp313-win_amd64.whl.metadata (9.9 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Downloading preshed-3.0.12-cp313-cp313-win_amd64.whl.metadata (2.6 kB)
# Collecting thinc<8.4.0,>=8.3.4 (from spacy)
#   Downloading thinc-8.3.10-cp313-cp313-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Downloading wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Downloading srsly-2.5.2-cp313-cp313-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.4.2 (from spacy)
#   Downloading weasel-0.4.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer-slim<1.0.0,>=0.3.0 (from spacy)
#   Downloading typer_slim-0.24.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\ksawe\appdata\roaming\python\python313\site-packages (from spacy) (4.67.3)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\ksawe\appdata\roaming\python\python313\site-packages (from spacy) (2.3.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\ksawe\appdata\roaming\python\python313\site-packages (from spacy) (2.32.5)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from spacy)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting jinja2 (from spacy)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting setuptools (from spacy)
#   Downloading setuptools-82.0.1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\ksawe\appdata\roaming\python\python313\site-packages (from spacy) (26.0)
# Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Downloading pydantic_core-2.41.5-cp313-cp313-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-extensions>=4.14.1 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ksawe\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ksawe\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ksawe\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ksawe\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.2.25)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.4->spacy)
#   Downloading blis-1.3.3-cp313-cp313-win_amd64.whl.metadata (7.7 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.4->spacy)
#   Downloading confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: colorama in c:\users\ksawe\appdata\roaming\python\python313\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Collecting typer>=0.24.0 (from typer-slim<1.0.0,>=0.3.0->spacy)
#   Downloading typer-0.24.1-py3-none-any.whl.metadata (16 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.4.2->spacy)
#   Downloading cloudpathlib-0.23.0-py3-none-any.whl.metadata (16 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.4.2->spacy)
#   Downloading smart_open-7.5.1-py3-none-any.whl.metadata (24 kB)
# Collecting wrapt (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy)
#   Downloading wrapt-2.1.2-cp313-cp313-win_amd64.whl.metadata (7.6 kB)
# Collecting click>=8.2.1 (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=12.3.0 (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy)
#   Downloading rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ksawe\appdata\roaming\python\python313\site-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->spacy)
#   Downloading markupsafe-3.0.3-cp313-cp313-win_amd64.whl.metadata (2.8 kB)
# Downloading spacy-3.8.11-cp313-cp313-win_amd64.whl (14.2 MB)
#    ---------------------------------------- 0.0/14.2 MB ? eta -:--:--
#    ------------- -------------------------- 4.7/14.2 MB 24.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 10.5/14.2 MB 26.0 MB/s eta 0:00:01
#    ---------------------------------------- 14.2/14.2 MB 25.5 MB/s  0:00:00
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.13-cp313-cp313-win_amd64.whl (40 kB)
# Downloading murmurhash-1.0.15-cp313-cp313-win_amd64.whl (25 kB)
# Downloading preshed-3.0.12-cp313-cp313-win_amd64.whl (117 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp313-cp313-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 27.1 MB/s  0:00:00
# Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.5.2-cp313-cp313-win_amd64.whl (653 kB)
#    ---------------------------------------- 0.0/653.1 kB ? eta -:--:--
#    ---------------------------------------- 653.1/653.1 kB 20.4 MB/s  0:00:00
# Downloading thinc-8.3.10-cp313-cp313-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 23.4 MB/s  0:00:00
# Downloading blis-1.3.3-cp313-cp313-win_amd64.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    -------------------------------------- - 6.0/6.2 MB 32.7 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 28.2 MB/s  0:00:00
# Downloading confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading typer_slim-0.24.0-py3-none-any.whl (3.4 kB)
# Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading weasel-0.4.3-py3-none-any.whl (50 kB)
# Downloading cloudpathlib-0.23.0-py3-none-any.whl (62 kB)
# Downloading smart_open-7.5.1-py3-none-any.whl (64 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading typer-0.24.1-py3-none-any.whl (56 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading rich-14.3.3-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading markupsafe-3.0.3-cp313-cp313-win_amd64.whl (15 kB)
# Downloading setuptools-82.0.1-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 26.0 MB/s  0:00:00
# Downloading wrapt-2.1.2-cp313-cp313-win_amd64.whl (60 kB)
# Installing collected packages: wrapt, wasabi, typing-extensions, spacy-loggers, spacy-legacy, shellingham, setuptools, murmurhash, mdurl, MarkupSafe, cymem, cloudpathlib, click, catalogue, blis, annotated-types, annotated-doc, typing-inspection, srsly, smart-open, pydantic-core, preshed, markdown-it-py, jinja2, rich, pydantic, typer, confection, typer-slim, thinc, weasel, spacy
#
#    ----------------------------------------  0/32 [wrapt]
#    ----------------------------------------  0/32 [wrapt]
#    - --------------------------------------  1/32 [wasabi]
#    - --------------------------------------  1/32 [wasabi]
#    - --------------------------------------  1/32 [wasabi]
#    --- ------------------------------------  3/32 [spacy-loggers]
#    --- ------------------------------------  3/32 [spacy-loggers]
#    --- ------------------------------------  3/32 [spacy-loggers]
#    ----- ----------------------------------  4/32 [spacy-legacy]
#    ----- ----------------------------------  4/32 [spacy-legacy]
#    ----- ----------------------------------  4/32 [spacy-legacy]
#    ------ ---------------------------------  5/32 [shellingham]
#    ------ ---------------------------------  5/32 [shellingham]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    ------- --------------------------------  6/32 [setuptools]
#    -------- -------------------------------  7/32 [murmurhash]
#    ---------- -----------------------------  8/32 [mdurl]
#    ----------- ----------------------------  9/32 [MarkupSafe]
#    ------------- -------------------------- 11/32 [cloudpathlib]
#    ------------- -------------------------- 11/32 [cloudpathlib]
#    ------------- -------------------------- 11/32 [cloudpathlib]
#    ------------- -------------------------- 11/32 [cloudpathlib]
#    ------------- -------------------------- 11/32 [cloudpathlib]
#    ------------- -------------------------- 11/32 [cloudpathlib]
#    --------------- ------------------------ 12/32 [click]
#    --------------- ------------------------ 12/32 [click]
#    --------------- ------------------------ 12/32 [click]
#    ---------------- ----------------------- 13/32 [catalogue]
#    ----------------- ---------------------- 14/32 [blis]
#    ----------------- ---------------------- 14/32 [blis]
#    ----------------- ---------------------- 14/32 [blis]
#    -------------------- ------------------- 16/32 [annotated-doc]
#    -------------------- ------------------- 16/32 [annotated-doc]
#    -------------------- ------------------- 16/32 [annotated-doc]
#    --------------------- ------------------ 17/32 [typing-inspection]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ---------------------- ----------------- 18/32 [srsly]
#    ----------------------- ---------------- 19/32 [smart-open]
#    ----------------------- ---------------- 19/32 [smart-open]
#    ----------------------- ---------------- 19/32 [smart-open]
#    ----------------------- ---------------- 19/32 [smart-open]
#    ------------------------- -------------- 20/32 [pydantic-core]
#    ------------------------- -------------- 20/32 [pydantic-core]
#    ------------------------- -------------- 20/32 [pydantic-core]
#    ------------------------- -------------- 20/32 [pydantic-core]
#    ------------------------- -------------- 20/32 [pydantic-core]
#    -------------------------- ------------- 21/32 [preshed]
#    -------------------------- ------------- 21/32 [preshed]
#    -------------------------- ------------- 21/32 [preshed]
#    -------------------------- ------------- 21/32 [preshed]
#    -------------------------- ------------- 21/32 [preshed]
#    -------------------------- ------------- 21/32 [preshed]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    --------------------------- ------------ 22/32 [markdown-it-py]
#    ---------------------------- ----------- 23/32 [jinja2]
#    ---------------------------- ----------- 23/32 [jinja2]
#    ---------------------------- ----------- 23/32 [jinja2]
#    ---------------------------- ----------- 23/32 [jinja2]
#    ---------------------------- ----------- 23/32 [jinja2]
#    ---------------------------- ----------- 23/32 [jinja2]
#    ---------------------------- ----------- 23/32 [jinja2]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------ --------- 24/32 [rich]
#    ------------------------------- -------- 25/32 [pydantic]
#    ------------------------------- -------- 25/32 [pydantic]
#    ------------------------------- -------- 25/32 [pydantic]
#    ------------------------------- -------- 25/32 [pydantic]
#    ------------------------------- -------- 25/32 [pydantic]
#    ------------------------------- -------- 25/32 [pydantic]
#    ------------------------------- -------- 25/32 [pydantic]
#    ------------------------------- -------- 25/32 [pydantic]
#    ------------------------------- -------- 25/32 [pydantic]
#    ------------------------------- -------- 25/32 [pydantic]
#    ------------------------------- -------- 25/32 [pydantic]
#    ------------------------------- -------- 25/32 [pydantic]
#    ------------------------------- -------- 25/32 [pydantic]
#    ------------------------------- -------- 25/32 [pydantic]
#    ------------------------------- -------- 25/32 [pydantic]
#    ------------------------------- -------- 25/32 [pydantic]
#    ------------------------------- -------- 25/32 [pydantic]
#    ------------------------------- -------- 25/32 [pydantic]
#    ------------------------------- -------- 25/32 [pydantic]
#    ------------------------------- -------- 25/32 [pydantic]
#    ------------------------------- -------- 25/32 [pydantic]
#    ------------------------------- -------- 25/32 [pydantic]
#    ------------------------------- -------- 25/32 [pydantic]
#    ------------------------------- -------- 25/32 [pydantic]
#    ------------------------------- -------- 25/32 [pydantic]
#    ------------------------------- -------- 25/32 [pydantic]
#    ------------------------------- -------- 25/32 [pydantic]
#    ------------------------------- -------- 25/32 [pydantic]
#    -------------------------------- ------- 26/32 [typer]
#    -------------------------------- ------- 26/32 [typer]
#    -------------------------------- ------- 26/32 [typer]
#    -------------------------------- ------- 26/32 [typer]
#    -------------------------------- ------- 26/32 [typer]
#    -------------------------------- ------- 26/32 [typer]
#    -------------------------------- ------- 26/32 [typer]
#    -------------------------------- ------- 26/32 [typer]
#    --------------------------------- ------ 27/32 [confection]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------ --- 29/32 [thinc]
#    ------------------------------------- -- 30/32 [weasel]
#    ------------------------------------- -- 30/32 [weasel]
#    ------------------------------------- -- 30/32 [weasel]
#    ------------------------------------- -- 30/32 [weasel]
#    ------------------------------------- -- 30/32 [weasel]
#    ------------------------------------- -- 30/32 [weasel]
#    ------------------------------------- -- 30/32 [weasel]
#    ------------------------------------- -- 30/32 [weasel]
#    ------------------------------------- -- 30/32 [weasel]
#    ------------------------------------- -- 30/32 [weasel]
#    ------------------------------------- -- 30/32 [weasel]
#    ------------------------------------- -- 30/32 [weasel]
#    ------------------------------------- -- 30/32 [weasel]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    -------------------------------------- - 31/32 [spacy]
#    ---------------------------------------- 32/32 [spacy]
#
# Successfully installed MarkupSafe-3.0.3 annotated-doc-0.0.4 annotated-types-0.7.0 blis-1.3.3 catalogue-2.0.10 click-8.3.1 cloudpathlib-0.23.0 confection-0.1.5 cymem-2.0.13 jinja2-3.1.6 markdown-it-py-4.0.0 mdurl-0.1.2 murmurhash-1.0.15 preshed-3.0.12 pydantic-2.12.5 pydantic-core-2.41.5 rich-14.3.3 setuptools-82.0.1 shellingham-1.5.4 smart-open-7.5.1 spacy-3.8.11 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.2 thinc-8.3.10 typer-0.24.1 typer-slim-0.24.0 typing-extensions-4.15.0 typing-inspection-0.4.2 wasabi-1.1.3 weasel-0.4.3 wrapt-2.1.2
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------- ------------------------------ 2.9/12.8 MB 18.0 MB/s eta 0:00:01
#      --------------------------- ------------ 8.7/12.8 MB 23.8 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 22.5 MB/s  0:00:00
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

doc = nlp(text)

for token in doc:
    print(token.lemma_)
# Out:
#
# for
# all
# Java
# programmer
# :
# this
# section
# explain
# how
# to
# compile
# and
# run
# a
# Swing
# application
# from
# the
# command
# line
# .
# for
# information
# on
# compile
# and
# run
# a
# swing
# application
# use
# NetBeans
# IDE
# ,
# see
# run
# Tutorial
# Examples
# in
# NetBeans
# IDE
# .
# the
# compilation
# instruction
# work
# for
# all
# Swing
# program
# —
# applet
# ,
# as
# well
# as
# application
# .
# here
# be
# the
# step
# you
# need
# to
# follow
# :
# install
# the
# late
# release
# of
# the
# Java
# SE
# platform
# ,
# if
# you
# have
# not
# already
# do
# so
# .
# create
# a
# program
# that
# use
# Swing
# component
# .
# compile
# the
# program
# .
# run
# the
# program
# .

# %% [markdown]
# Sukces! Nastąpił podział tekstu na słowa (tokenizacja) oraz sprowadzenie do formy podstawowej każdego słowa (lematyzacja).

# %% [markdown]
# ### Ćwiczenie 3: Zmodyfikuj program z ćwiczenia 2 tak, aby zwracał również odmienione słowa. Na przykład, dla słowa "program" powinien znaleźć również "programs", ustawiając pozycje w tekście odpowiednio dla słowa "programs". Wykorzystaj właściwość idx tokenu.

# %%
def terminology_lookup(text, dictionary):
    doc = nlp(text)
    
    results = {term: [] for term in dictionary}
    for token in doc:
        lemma = token.lemma_.lower()
        
        if lemma in dictionary:
            start = token.idx
            end = start + len(token.text)
            
            results[lemma].append((start, end))
            
    return results

found_terms = terminology_lookup(text, dictionary)

for term, positions in found_terms.items():
    print(f"Termin słownikowy: '{term}'")
    if positions:
        for pos in positions:
            original_word = text[pos[0]:pos[1]]
            print(f"  - Znaleziono: '{original_word}' na pozycji {pos}")
    else:
        print("  - Nie znaleziono.")
# Out:
# Termin słownikowy: 'program'
#   - Znaleziono: 'programs' na pozycji (291, 299)
#   - Znaleziono: 'program' na pozycji (468, 475)
#   - Znaleziono: 'program' na pozycji (516, 523)
#   - Znaleziono: 'program' na pozycji (533, 540)
# Termin słownikowy: 'application'
#   - Znaleziono: 'application' na pozycji (80, 91)
#   - Znaleziono: 'application' na pozycji (164, 175)
#   - Znaleziono: 'applications' na pozycji (322, 334)
# Termin słownikowy: 'applet'
#   - Znaleziono: 'applets' na pozycji (302, 309)
# Termin słownikowy: 'compile'
#   - Znaleziono: 'compile' na pozycji (56, 63)
#   - Znaleziono: 'compiling' na pozycji (134, 143)
#   - Znaleziono: 'Compile' na pozycji (504, 511)

# %% [markdown]
# Teraz czas zająć się problemem przygotowania słownika specjalistycznego. W tym celu napiszemy nasz własny ekstraktor terminologii. Wejściem do ekstraktora będzie tekst zawierający specjalistyczną terminologię. Wyjściem - lista terminów.

# %% [markdown]
# Przyjmijmy następujące podejście - terminami specjalistycznymi będą najcześćiej występujące rzeczowniki w tekście. Wykonajmy krok pierwszy:

# %% [markdown]
# ### Ćwiczenie 4: Wypisz wszystkie rzeczowniki z tekstu. Wykorzystaj możliwości spaCy.

# %%
def get_nouns(text):
    doc = nlp(text)
    nouns = [token.text for token in doc if token.pos_ in ["NOUN", "PROPN"]]
    return nouns

all_nouns = get_nouns(text)

print(f"Znaleziono {len(all_nouns)} rzeczowników:")
print(all_nouns)
# Out:
# Znaleziono 32 rzeczowników:
# ['Java', 'programmers', 'section', 'Swing', 'application', 'command', 'line', 'information', 'Swing', 'application', 'NetBeans', 'IDE', 'Tutorial', 'Examples', 'NetBeans', 'IDE', 'compilation', 'instructions', 'Swing', 'programs', 'applets', 'applications', 'steps', 'release', 'Java', 'SE', 'platform', 'program', 'Swing', 'components', 'program', 'program']

# %% [markdown]
# Teraz czas na podliczenie wystąpień poszczególnych rzeczowników. Uwaga - różne formy tego samego słowa zliczamy razem jako wystąpienia tego słowa (np. "program" i "programs"). Najwygodniejszą metodą podliczania jest zastosowanie tzw. tally (po polsku "zestawienie"). Jest to słownik, którego kluczem jest słowo w formie podstawowej, a wartością liczba wystąpień tego słowa, wliczając słowa odmienione. Przykład gotowego tally:

# %%
tally = {"program" : 4, "component" : 1}

# %% [markdown]
# ### Ćwiczenie 5: Napisz program do ekstrakcji terminologii z tekstu według powyższych wytycznych.

# %%
def extract_terms(text):
    doc = nlp(text)

    tally = {}
    
    for token in doc:
        if token.pos_ in ["NOUN", "PROPN"]:
            lemma = token.lemma_.lower()
        
            if lemma in tally:
                tally[lemma] += 1
            else:
                tally[lemma] = 1
                
    return tally

text = "Create a program. This program uses Swing components. Run the programs."
wynik = extract_terms(text)
print(wynik)
# Out:
# {'program': 3, 'swing': 1, 'component': 1}

# %% [markdown]
# ### Ćwiczenie 6: Rozszerz powyższy program o ekstrację czasowników i przymiotników.

# %%
import spacy
from collections import Counter

nlp = spacy.load("en_core_web_sm")

def extract_terms(text):
    doc = nlp(text)
    allowed_pos = ["NOUN", "PROPN", "VERB", "ADJ"]
    
    lemmas = [
        token.lemma_.lower() 
        for token in doc 
        if token.pos_ in allowed_pos
    ]
    
    return dict(Counter(lemmas))

tally_result = extract_terms(text)
print(tally_result)
# Out:
# {'create': 1, 'program': 3, 'use': 1, 'swing': 1, 'component': 1, 'run': 1}
