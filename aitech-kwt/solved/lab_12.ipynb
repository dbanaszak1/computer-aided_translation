# %% [markdown]
# ![Logo 1](https://git.wmi.amu.edu.pl/AITech/Szablon/raw/branch/master/Logotyp_AITech1.jpg)
# <div class="alert alert-block alert-info">
# <h1> Komputerowe wspomaganie tłumaczenia </h1>
# <h2> 12. <i>Key logging</i> [laboratoria]</h2>
# <h3>Rafał Jaworski (2021)</h3>
# </div>
#
# ![Logo 2](https://git.wmi.amu.edu.pl/AITech/Szablon/raw/branch/master/Logotyp_AITech2.jpg)

# %% [markdown]
# Badania nad komputerowym wspomaganiem tłumaczenia często prowadzone są przy użyciu metodologii testowania interfejsów użytkownika - UI/UX testing. Program typu CAT traktuje się wówczas jak każdy inny program komputerowy i przeprowadza testy wydajności i użyteczności.

# %% [markdown]
# Testy takie prowadzone są zawsze na użytkownikach końcowych, w tym przypadku - na tłumaczach. Podstawowym celem testów jest próba zaobserwowania faktycznego sposobu pracy tłumacza - które funkcje programu są przez niego wykorzystywane najczęściej, jakich innych narzędzi poza CAT-em używa on do swojej pracy, które funkcje programu działają zgodnie, a które niezgodnie z intuicją użytkownika oraz wiele innych czynników. Aby wszystkie te analizy były możliwe, konieczne jest zgromadzenie jak największej ilości danych dotyczących przebiegu testu.

# %% [markdown]
# Testy są przede wszystkim nagrywane. Nagrywany jest zarówno ekran komputera (screen capture), jak i sam użytkownik pracujący przy komputerze. To jednak nie wszystko - często stosuje się specjalne techniki eye-trackingu, które są w stanie określić, w który punk ekranu użytkownik aktualnie patrzy. Dane pozyskane w ten sposób używane są do analizy czasu znalezienia przez użytkownika potrzebnej mu funkcji oraz zidentyfikowania miejsc, gdzie tej funkcji poszukiwał. Można również wyznaczyć obszary ekranu, które często skupiają uwagę użytkownika.

# %% [markdown]
# Dodatkowo stosuje się jeszcze jedną technikę, która jest szczególnie przydatna z punktu widzenia analizy procesu tłumaczenia. Wykonuje się pełny key logging, tj. zapisuje się każde uderzenie użytkownika w dowolny klawisz na klawiaturze wraz z precyzyjnym czasem tego uderzenia. Dane pozyskane w ten sposób pozwalają na przeprowadzenie szeregu interesujących analiz.

# %% [markdown]
# Zapoznajmy się najpierw z programem typu key logger:

# %% [markdown]
# `sudo pip3 install keyboard`

# %%
import keyboard


def report_key(event):
    print(event)

keyboard.on_release(callback=report_key)
keyboard.wait()

# %% [markdown]
# (.venv) dbanaszak@dbanaszak-thinkpad:~/projects/ai_translation_support$   sudo .venv/bin/python aitech-kwt/lab/tmp/tmp1.py
# KeyboardEvent(n up)
# KeyboardEvent(a up)
# KeyboardEvent(n up)
# KeyboardEvent(o up)
# KeyboardEvent(space up)
# KeyboardEvent(t up)
# KeyboardEvent(e up)
# KeyboardEvent(s up)
# KeyboardEvent(t up)
# KeyboardEvent(space up)
# KeyboardEvent(backspace up)
# KeyboardEvent(. up)
# KeyboardEvent(t up)
# KeyboardEvent(x up)
# KeyboardEvent(t up)
# KeyboardEvent(enter up)
# KeyboardEvent(p up)
# KeyboardEvent(shift up)
# KeyboardEvent(i up)
# KeyboardEvent(s up)
# KeyboardEvent(alt gr up)
# KeyboardEvent(z up)
# KeyboardEvent(e up)
# KeyboardEvent(space up)
# KeyboardEvent(backspace up)
# KeyboardEvent(backspace up)
# KeyboardEvent(backspace up)
# KeyboardEvent(backspace up)
# KeyboardEvent(s up)
# KeyboardEvent(z up)
# KeyboardEvent(alt gr up)
# KeyboardEvent(e up)
# KeyboardEvent(space up)
# KeyboardEvent(c up)
# KeyboardEvent(o up)
# KeyboardEvent(k up)
# KeyboardEvent(o up)
# KeyboardEvent(l up)
# KeyboardEvent(w up)
# KeyboardEvent(u up)
# KeyboardEvent(e up)
# KeyboardEvent(k up)
# KeyboardEvent(space up)
# KeyboardEvent(w up)
# KeyboardEvent(space up)
# KeyboardEvent(p up)
# KeyboardEvent(l up)
# KeyboardEvent(i up)
# KeyboardEvent(k up)
# KeyboardEvent(u up)
# KeyboardEvent(space up)
# KeyboardEvent(t up)
# KeyboardEvent(e up)
# KeyboardEvent(s up)
# KeyboardEvent(t up)
# KeyboardEvent(. up)
# KeyboardEvent(t up)
# KeyboardEvent(x up)
# KeyboardEvent(t up)
# KeyboardEvent(ctrl up)
# KeyboardEvent(s up)
# KeyboardEvent(x up)
# KeyboardEvent(ctrl up)
# ^CTraceback (most recent call last):

# %% [markdown]
# UWAGA! Aby uruchomić powyższy kod na Linuxie konieczne są uprawnienia administratora (pytanie poza konkursem - dlaczego?)

# %% [markdown]
# ### Ćwiczenie 1: Wykorzystując powyższy kod napisz keylogger, który zapisuje wszystkie uderzenia w klawisze do pliku. Format pliku jest dowolny, każdy wpis musi zawierać precyzyjną godzinę uderzenia oraz uderzony klawisz. Uruchom program i przepisz paragraf dowolnie wybranego tekstu.

# %%
import json
from datetime import datetime
from pathlib import Path

import keyboard


def key_to_char(key_name):
    special_keys = {
        'space': ' ',
        'enter': '\n',
        'tab': '\t',
        'backspace': '\b',
    }

    if key_name in special_keys:
        return special_keys[key_name]
    if len(key_name) == 1:
        return key_name
    return ''


def start_keylogger(log_path='keylog.jsonl', stop_key='esc'):
    log_path = Path(log_path)

    def save_key(event):
        entry = {
            'timestamp': datetime.now().isoformat(timespec='microseconds'),
            'key': event.name,
            'char': key_to_char(event.name),
        }

        with log_path.open('a', encoding='utf-8') as file:
            file.write(json.dumps(entry, ensure_ascii=False) + '\n')

    keyboard.on_release(callback=save_key)
    print(f'Log file {log_path}. Stop key {stop_key}')
    keyboard.wait(stop_key)
    keyboard.unhook_all()


start_keylogger('keylog.jsonl')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       1 import json
#       2 from datetime import datetime
#       3 from pathlib import Path
#       4
# ----> 5 import keyboard
#       6
#       7
#       8 def key_to_char(key_name):
#
# ModuleNotFoundError: No module named 'keyboard'

# %%
{"timestamp": "2026-05-17T13:18:38.897489", "key": "shift", "char": ""}
{"timestamp": "2026-05-17T13:18:38.916219", "key": "p", "char": "p"}
{"timestamp": "2026-05-17T13:18:39.030440", "key": "o", "char": "o"}
{"timestamp": "2026-05-17T13
"key": "o", "char": "o"}
{"timestamp": "2026-05-17T13:19:50.435528", "key": "p", "char": "p"}
{"timestamp": "2026-05-17T13:19:50.609093", "key": "u", "char": "u"}
{"timestamp": "2026-05-17T13:19:50.671759", "key": "s", "char": "s"}
{"timestamp": "2026-05-17T13:19:50.885637", "key": "z", "char": "z"}
{"timestamp": "2026-05-17T13:19:51.179265", "key": "c", "char": "c"}
{"timestamp": "2026-05-17T13:19:51.238842", "key": "z", "char": "z"}
{"timestamp": "2026-05-17T13:19:51.442114", "key": "a", "char": "a"}
{"timestamp": "2026-05-17T13:19:51.754991", "key": "space", "char": " "}
{"timestamp": "2026-05-17T13:19:52.022080", "key": "d", "char": "d"}
{"timestamp": "2026-05-17T13:19:52.095625", "key": "i", "char": "i"}
{"timestamp": "2026-05-17T13:19:52.577859", "key": "backspace", "char": "\b"}
{"timestamp": "2026-05-17T13:19:52.762387", "key": "u", "char": "u"}
{"timestamp": "2026-05-17T13:19:52.933433", "key": "m", "char": "m"}
{"timestamp": "2026-05-17T13:19:53.054430", "key": "e", "char": "e"}
{"timestamp": "2026-05-17T13:19:53.077357", "key": "space", "char": " "}
{"timestamp": "2026-05-17T13:19:53.236583", "key": "k", "char": "k"}
{"timestamp": "2026-05-17T13:19:53.327296", "key": "a", "char": "a"}
{"timestamp": "2026-05-17T13:19:53.511611", "key": "t", "char": "t"}
{"timestamp": "2026-05-17T13:19:53.731762", "key": "a", "char": "a"}
{"timestamp": "2026-05-17T13:19:53.755885", "key": "l", "char": "l"}
{"timestamp": "2026-05-17T13:19:53.891696", "key": "o", "char": "o"}
{"timestamp": "2026-05-17T13:19:54.064150", "key": "n", "char": "n"}
{"timestamp": "2026-05-17T13:19:54.117500", "key": "i", "char": "i"}
{"timestamp": "2026-05-17T13:19:54.943753", "key": ".", "char": "."}

# %% [markdown]
# Celem powyższego ćwiczenia jest pozyskanie danych testowych. Dalsze analizy będziemy prowadzili już bez key loggera, starając się korzystać jedynie z danych zapisanych w pliku. Oczywiście, jeśli zajdzie taka konieczność, można w każdej chwili wygenerować sobie nowy plik.

# %% [markdown]
# ### Ćwiczenie 2: Napisz program, który wyliczy średnią prędkość pisania. Wykryj, kiedy użytkownik zaczął pisać. Nie bierz pod uwagę przerw dłuższych niż 5 sekund. Podaj prędkość pisania w znakach na minutę oraz słowach na minutę.

# %%
from datetime import datetime
import json
import re


def load_keylog(log_path='keylog.jsonl'):
    events = []

    with open(log_path, encoding='utf-8') as file:
        for line in file:
            if not line.strip():
                continue

            event = json.loads(line)
            event['timestamp'] = datetime.fromisoformat(event['timestamp'])
            events.append(event)

    return events


def reconstruct_text(events):
    text = []

    for event in events:
        char = event.get('char', '')

        if char == '\b':
            if text:
                text.pop()
        elif char:
            text.append(char)

    return ''.join(text)


def calculate_typing_speed(log_path='keylog.jsonl', max_pause_seconds=5):
    events = [event for event in load_keylog(log_path) if event.get('char')]

    if not events:
        return {'chars_per_minute': 0, 'words_per_minute': 0, 'active_seconds': 0}

    active_seconds = 0
    for previous, current in zip(events, events[1:]):
        pause = (current['timestamp'] - previous['timestamp']).total_seconds()
        if pause <= max_pause_seconds:
            active_seconds += pause

    text = reconstruct_text(events)
    chars = len(text)
    words = len(re.findall(r'\S+', text))

    if active_seconds == 0:
        return {'chars_per_minute': chars, 'words_per_minute': words, 'active_seconds': 0}

    active_minutes = active_seconds / 60
    return {
        'chars': chars,
        'words': words,
        'active_seconds': active_seconds,
        'chars_per_minute': chars / active_minutes,
        'words_per_minute': words / active_minutes,
    }


# calculate_typing_speed('keylog.jsonl')

# %%
{'chars': 306, 'words': 41, 'active_seconds': 76.02753399999996, 'chars_per_minute': 241.4914575553642, 'words_per_minute': 32.35669856133965}

# %% [markdown]
# Wróćmy teraz do procesu tłumaczenia. Analiza uderzeń klawiszy wykonanych podczas tłumaczenia pozwala wykryć dłuższe pauzy. Pauzy te najczęściej wskazują miejsca, w których tłumacz musi się głębiej zastanowić nad tłumaczeniem danego słowa lub frazy. Przerwę tę wykorzystuje na przykład na sprawdzenie tłumaczenia lub definicji w słowniku, przeglądanie wyników z pamięci tłumaczeń lub korzystanie z innych pomocy (eye-tracking mógłby w tym przypadku rozstrzygnąć, czym w istocie zajmuje się w tym momencie tłuamcz). Jest też możliwe, że tłumacz poświęca pauzę na tzw. cognitive pause-and-unload - rodzaj zamyślenia, pozwalający oczyścić myśli. Z punktu widzenia projektowania systemu wspomagającego tłumaczenie niezwykle istotna jest informacja, nad czym tłumacz musi się dłużej zastanowić. Minimalizacja liczby i czasu trwania takich przerw jest szansą na usprawnienie procesu tłumaczenia.

# %% [markdown]
# ### Ćwiczenie 3: Napisz program do wykrywania przerw w pisaniu. Raportuj długość oraz miejsce wystąpienia przerwy podając 20-znakowy kontekst z każdej strony. Wykryj każdą przerwę dłuższą niż 3 sekundy, posortuj wyniki malejąco po długości przerwy.

# %%
def find_pauses(log_path='keylog.jsonl', min_pause_seconds=3, context_size=20):
    events = [event for event in load_keylog(log_path) if event.get('char')]
    pauses = []

    for index, (previous, current) in enumerate(zip(events, events[1:])):
        pause = (current['timestamp'] - previous['timestamp']).total_seconds()

        if pause <= min_pause_seconds:
            continue

        text_before = reconstruct_text(events[:index + 1])
        text_after = reconstruct_text(events[index + 1:])

        pauses.append({
            'pause_seconds': pause,
            'position': len(text_before),
            'left_context': text_before[-context_size:],
            'right_context': text_after[:context_size],
        })

    return sorted(pauses, key=lambda pause: pause['pause_seconds'], reverse=True)


# find_pauses('keylog.jsonl')

# %%
[{'pause_seconds': 429.005039, 'position': 306, 'left_context': 'szcza dume kataloni.', 'right_context': 'po tygodniach spekul'}, {'pause_seconds': 5.167899, 'position': 345, 'left_context': 'lacji i niepernosci ', 'right_context': 'rozstanie rlewandows'}, {'pause_seconds': 4.948968, 'position': 426, 'left_context': 'eprezantacji polski ', 'right_context': 'w ostatnims`'}, {'pause_seconds': 3.278141, 'position': 320, 'left_context': 'aloni.po tygodniach ', 'right_context': 'spekulacji i niepern'}, {'pause_seconds': 3.199674, 'position': 371, 'left_context': 'nie rlewandowskiego ', 'right_context': 'z Barca staje sie fa'}]
